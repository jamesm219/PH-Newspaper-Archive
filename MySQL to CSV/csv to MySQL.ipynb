# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# %%
df = pd.read_csv('with_score.csv')

# %%
df['label'] = df['label'].str.replace('LABEL_0', 'NEGATIVE')
df['label'] = df['label'].str.replace('LABEL_1', 'NEUTRAL')
df['label'] = df['label'].str.replace('LABEL_2', 'POSITIVE')
df
# Out:
#       article_id                                              title  \
# 0              1  Palace warns vs Marcos deepfake audio ordering...
# 1              2  PAGASA: 30 areas under ‘dangerous’ heat index ...
# 2              3  Number of Chinese vessels surges in West Phili...
# 3              4  China says committed to 'friendly' talks on ma...
# 4              5  'So hot you can't breathe': Extreme heat hits ...
# ...          ...                                                ...
# 4300        6601  2GO: 630 ship passengers safely reach Palawan ...
# 4301        6602  CHR asks gov't to ensure safety of 6,000 displ...
# 4302        6603  Court officials, employees must adopt reforms ...
# 4303        6604  Ex-Mindanao State U chancellor convicted of gr...
# 4304        6605   Militants call on China to stop WPS 'harassment'
#
#                                          author        date  \
# 0                                  Philstar.com  2024-04-24
# ...

# %%
db_connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Getgood1234",
    database="ph_newspaper"
)

# %%
cursor = db_connection.cursor()

# %%
# Replace 'username', 'password', 'hostname', 'database_name' with your MySQL credentials
engine = create_engine('mysql+mysqlconnector://root:Getgood1234@localhost/ph_newspaper')

# %%
df.to_sql('sentiment', con=engine, if_exists='append', index=False)
# Out:
# -1
