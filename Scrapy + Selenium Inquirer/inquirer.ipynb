# %%
import pandas as pd
import requests
import mysql.connector
from sqlalchemy import create_engine

# %%
df = pd.read_csv('inquirer.csv')

# %%
df['date'] = df['date'].str.split(' ').str[-3:].str.join(' ')

df['date'] = df['date'].str.replace('June', 'Jun')

df['date'] = df['date'].str.replace('July', 'Jul')

df['date'] = df['date'].str.replace('April', 'Apr')

df['date'] = df['date'].str.replace(',', '')

# %%
df['date'] = pd.to_datetime(df['date'], format='%b %d %Y')

df['date'] = df['date'].astype('datetime64[ns]')

# %%
import numpy as np

df['title'].replace('', np.nan, inplace=True)
df.dropna(subset=['title'], inplace=True)
df
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_6716\183566453.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['title'].replace('', np.nan, inplace=True)
#                                                 title  \
# 0   2024 CSR Conference and Expo in July spotlight...
# 1   Caribbean on alert for Hurricane Beryl, first ...
# 2   Negros cops to file raps vs 2 suspects in Amor...
# 3   Successful Cultural Exchange: Project: Ligaya ...
# 4   African leaders urge UN to prioritize tree pla...
# 5   First fatal human case of H5N2 bird flu identi...
# 6   Deadpool and Wolverine movie screening for ani...
# 7   How microfragmentation can help restore coral ...
# 8   Hajj pilgrims ‘stone the devil’ as Muslims mar...
# 9   Famous oceanographer visits PH to urge Verde I...
# 10  Why some workers might view a manager’s toxic ...
# 11      PH, US tackle Edca, maritime domain awareness
# 12          Marcos: Going ‘green’ good for PH tourism
# 13  Alice Guo may have left PH using Chinese passp...
# 14  Creation of village in South Cotabato protecte...
# 15  Transforms stigma into opportunity as Filipino...
# 16   BIR: Online sellers must now pay withholding tax
# 17  MMDA and partners unveil San Juan EcoBridge re...
# 18  Cavite City in state of calamity due to massiv...
# 19      Bangsamoro folk told to brace for more floods
# 20        7 regions report sharp hike in dengue cases
# 21  Raided Pogo in Pasay City now a shelter for ho...
# 22  INQToday: Gatchalian reports threats made agai...
# 23  Ex-Caloocan Mayor Malonzo files graft rap vs R...
# 24  Tiangco lauds ‘Program 29’: 1,500 Navotas resi...
# 25  Caloocan official: Graft rap vs Rep. Malapitan...
# 26       Navy missile boat gets battle system upgrade
# 27             NKTI probes alleged kidney trafficking
# 28  Gatchalian says Guo’s life wouldn’t be normal ...
# 29  Pagasa: LPA, ‘habagat’ combine to bring rainy ...
# 30  Marcos pre-Sona approval, trust ratings dip; V...
# 31                Injured dolphin rescued in Batangas
# 32  2 hurt in Lucena City shooting incident trigge...
# 33  Will Marcos mention Pogos in Sona? Tell PNP to...
# 34  Iloilo City mayor calls out DPWH on project de...
# 35      Escudero welcomes trust rating survey results
#
#                                        author       date  \
# 0                                         NaN 2024-06-27
# 1                                         NaN 2024-06-30
# 2               Carla P. Gomez @carlagomezINQ 2024-07-17
# 3                                         NaN 2024-07-08
# 4                                         NaN 2024-07-06
# 5                                         NaN 2024-06-06
# 6                                         NaN 2024-07-12
# 7                                         NaN 2024-07-06
# 8                                         NaN 2024-06-17
# 9                                Luisa Cabato 2024-07-06
# 10                                        NaN 2024-07-13
# 11                              Charie Abarca 2024-07-17
# 12                           Julie M. Aurelio 2024-06-29
# 13                                 Maila Ager 2024-07-17
# 14                             Bong Sarmiento 2024-07-12
# 15                                        NaN 2024-07-15
# 16                 Mariedel Irish U. Catilogo 2024-07-17
# 7   https://globalnation.inquirer.net/241677/how-r...
# 8   https://newsinfo.inquirer.net/1952400/hajj-pil...
# 9   https://globalnation.inquirer.net/241753/renow...
# 10  https://newsinfo.inquirer.net/1960759/why-some...
# 11  https://globalnation.inquirer.net/242914/fwd-p...
# 12  https://newsinfo.inquirer.net/1956137/marcos-g...
# 13  https://globalnation.inquirer.net/242921/alice...
# 14  https://newsinfo.inquirer.net/1960474/creation...
# 15  https://globalnation.inquirer.net/242419/trans...
# 16  https://newsinfo.inquirer.net/1961672/bir-onli...
# 17  https://globalnation.inquirer.net/242680/mmda-...
# 18  https://newsinfo.inquirer.net/1961650/cavite-c...
# 19  https://newsinfo.inquirer.net/1961643/bangsamo...
# 20  https://newsinfo.inquirer.net/1961688/7-region...
# 21  https://newsinfo.inquirer.net/1960859/raided-p...
# 22  https://newsinfo.inquirer.net/1961523/inqtoday...
# 23  https://newsinfo.inquirer.net/1961589/ex-caloo...
# 24  https://newsinfo.inquirer.net/1961602/tiangco-...
# 25  https://newsinfo.inquirer.net/1961599/caloocan...
# 26  https://newsinfo.inquirer.net/1961615/navy-mis...
# 27  https://newsinfo.inquirer.net/1961628/nkti-pro...
# 28  https://newsinfo.inquirer.net/1961663/gatchali...
# 29  https://newsinfo.inquirer.net/1961764/pagasa-r...
# 30  https://newsinfo.inquirer.net/1961771/marcos-a...
# 31  https://newsinfo.inquirer.net/1961769/injured-...
# 32  https://newsinfo.inquirer.net/1961781/2-hurt-i...
# 33  https://newsinfo.inquirer.net/1961791/will-mar...
# 34  https://newsinfo.inquirer.net/1961785/iloilo-c...
# 35  https://newsinfo.inquirer.net/1961808/fwd-escu...

# %%
import textwrap
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")

sentiment = pipeline("text-classification", model=model, tokenizer=tokenizer)

sentiment_scores = []
label = []

for title in df['title']:
    score = sentiment(title)
    sentiment_scores.append(score[0]['score'])
    label.append(score[0]['label'])

# %%
transformers_data = {
    'score': sentiment_scores,
    'label': label
}

df2 = pd.DataFrame(transformers_data)

df2['label'] = df2['label'].str.replace('LABEL_0', 'NEGATIVE')
df2['label'] = df2['label'].str.replace('LABEL_1', 'NEUTRAL')
df2['label'] = df2['label'].str.replace('LABEL_2', 'POSITIVE')

df3 = pd.concat([df, df2], axis=1)

# %%
db_connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="****",
    database="ph_newspaper"
)

# %%
cursor = db_connection.cursor()

# %%
engine = create_engine('mysql+mysqlconnector://root:****@localhost/ph_newspaper')

# %%
df3.to_sql('philstar', con=engine, if_exists='append', index=False)
# Out:
# -1

# %%
try:
    cursor.execute("""
        SELECT title, MIN(article_id) AS min_article_id
        FROM philstar
        GROUP BY title
        HAVING COUNT(*) > 1
    """)
    duplicate_titles = cursor.fetchall()

    for title, min_article_id in duplicate_titles:
        cursor.execute("""
            DELETE FROM philstar
            WHERE title = %s AND article_id <> %s
        """, (title, min_article_id))
    
    cursor.execute("""UPDATE philstar
    SET date = REPLACE(date, ' , / ', '')""")

    cursor.execute("""UPDATE philstar
    SET date = TRIM(date)""")

    db_connection.commit()
    print("Duplicate entries have been deleted.")

except mysql.connector.Error as e:
    print("Error:", e)

finally:
    cursor.close()
    db_connection.close()
# Out:
# Duplicate entries have been deleted.
